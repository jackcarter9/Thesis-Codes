# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import pymc3 as pm 
import os 

font = {'family' : 'Arial',
        'weight' : 'normal',
        'size'   : 15}

plt.rc('font', **font)
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
from scipy import stats
from pymc3.distributions import draw_values
from pymc3.distributions import generate_samples
from pymc3.theanof import floatX
from pymc3.distributions.dist_math import bound
from pymc3.distributions import (Continuous, draw_values, generate_samples)

def assert_negative_support(var, label, distname, value=-1e-6):
    # Checks for evidence of positive support for a variable
    if var is None:
        return
    try:
        # Transformed distribution
        support = np.isfinite(var.transformed.distribution.dist
                              .logp(value).tag.test_value)
    except AttributeError:
        try:
            # Untransformed distribution
            support = np.isfinite(var.distribution.logp(value).tag.test_value)
        except AttributeError:
            # Otherwise no direct evidence of non-positive support
            support = False

    if np.any(support):
        msg = "The variable specified for {0} has negative support for {1}, ".format(
            label, distname)
        msg += "likely making it unsuitable for this parameter."
        warnings.warn(msg)

def get_tau_sigma(tau=None, sigma=None):
    if tau is None:
        if sigma is None:
            sigma = 1.
            tau = 1.
        else:
            tau = sigma**-2.
    else:
        if sigma is not None:
            raise ValueError("Can't pass both tau and sigma")
        else:
            sigma = tau**-.5
    tau = 1. * tau
    sigma = 1. * sigma
    return floatX(tau), floatX(sigma)



class weighted_Normal(pm.distributions.Continuous):

    def __init__(self, mu=0, sigma=None, tau=None, sd=None, weight =None,**kwargs):
        if sd is not None:
            sigma = sd
        tau, sigma = get_tau_sigma(tau=tau, sigma=sigma)
        self.sigma = self.sd = tt.as_tensor_variable(sigma)
        self.tau = tt.as_tensor_variable(tau)
        self.weight = tt.as_tensor_variable(weight)

        self.mean = self.median = self.mode = self.mu = mu = tt.as_tensor_variable(floatX(mu))
        self.variance = 1. / self.tau

        assert_negative_support(sigma, 'sigma', 'Normal')
        assert_negative_support(tau, 'tau', 'Normal')

        super().__init__(**kwargs)

    def random(self, point=None, size=None):
        
        mu, tau, _ = draw_values([self.mu, self.tau, self.sigma],
                                 point=point, size=size)
        return generate_samples(stats.norm.rvs, loc=mu, scale=tau**-0.5,
                                dist_shape=self.shape,
                                size=size)

    def logp(self, value):
        """
        Sum of Squares
        
        """
        sigma = self.sigma
        tau = self.tau
        mu = self.mu
        weight = self.weight
        
        logp =  - weight.T * tt.sqr(value - mu)/(2.0 * sigma * sigma)
        return logp.sum()

# %%
import pandas as pd
cwd = os.chdir('/Users/jackcarter/Documents/Data_Mixtures')
df = pd.read_csv("jc_anorthite_diff_data_y.csv")

# %%
df.head()
# Out:
#          Age     Age_Er     Ar40_   Ar40_Er     Ar39_   Ar39_Er  Pwr_Achieved  \
# 0  3009.8450   44.32490  0.883571  0.000660  0.001935  0.000064           421
# 1  1174.0770  221.15590  0.019850  0.000099  0.000160  0.000018           422
# 2   608.5527   58.62154  0.084759  0.000071  0.000963  0.000023           468
# 3   572.1960   57.82173  0.066172  0.000110  0.001102  0.000046           510
# 4   575.0047  149.66360  0.015383  0.000064  0.000262  0.000038           511
#
#    Dur_Heating_At_Req_Pwr       Da2       Da2_err
# 0                     596  0.000010  2.710000e-20
# 1                     596  0.000005  1.430000e-09
# 2                     596  0.000034  1.430000e-07
# 3                     596  0.000050  1.560000e-07
# 4                     596  0.000014  2.270000e-07

# %%
temp = df['Pwr_Achieved'].values
time = df['Dur_Heating_At_Req_Pwr'].values
ar39 = df['Ar39_'].values
ar39_err = df['Ar39_Er'].values

# %%
"""
Remove Nan
"""
temp = temp[~np.isnan(temp)]
time = time[~np.isnan(time)]
ar39 = ar39[~np.isnan(ar39)]

# %%
# Part 1 ThermoCouple T Calibration 
## Step 1: Pyrometer Calibration
import os 
cwd = os.getcwd()
os.chdir("/Users/jackcarter/Desktop/Downloads")
df1 = pd.read_csv("PyroApril2018.csv")
c1 = df1.iloc[:,0:1]
c2 = df1.iloc[:,1:2]
x1 = c1.values
x2 = c2.values
x1 = x1[x1 >=0]
x2 = x2[x2 >=0]
ThermoT = x2
PyroT = x1
zpt = np.polyfit(x1,x2,3)

# %%
temp = np.polyval(zpt, temp)

# %%
da2 = df['Da2'].values
da2_err = df['Da2_err'].values
da2 = da2[~np.isnan(da2)]
da2_err = da2_err[~np.isnan(da2_err)]

# %%
tplot = 1e4/(temp + 273.15)

# %%
"""
Plot Style
"""

font = {'family' : 'Arial',
        'weight' : 'normal',
        'size'   : 15}

plt.rc('font', **font) 
sns.set_style('ticks')

# %%
def cumrel(x): 
    y = np.cumsum(x)
    z = y/y.max()
    return z

# %%
ar39 = cumrel(ar39)
age = df['Age'].values
age = age[~np.isnan(age)]
age_err = df['Age_Er'].values
age_err = age_err[~np.isnan(age_err)]
data3 = ar39

# %%
# Plotting parameters

age_plot = np.insert(age,
                     0, age[0])
age_plot_err =  np.insert(age_err, 
                         0, age_err[0])
ar39_plot = np.insert(ar39,
                      0, 0)

# %%
fig, ax = plt.subplots(1, 2, figsize = (8,5))

ax[0].fill_between(ar39_plot, 
                age_plot + age_plot_err, 
                age_plot - age_plot_err, 
                facecolor = 'orange', 
                step = 'pre', 
                  edgecolor = 'k', 
                  lw = 0.4
                  )

ax[0].set_xlim(0,1)

ax[0].set_ylabel('Apparent Age (Ma)')
ax[0].set_xlabel('Normalised cumulative $^{39}$Ar\nreleased');
ax[1].errorbar(tplot, np.log(da2),
             yerr = (da2_err/da2),
       fmt =  'o', 
        markersize = 10, 
        color = 'orange', 
        markeredgecolor = 'k')

ax[1].set_xlabel('10$^{4}$/T (K$^{-1}$))')
ax[1].set_ylabel('ln(D/$a^{2}$)')
ax[1].set_ylim(-14, -6)
ax[0].set_ylim(0, 3000)
plt.tight_layout()

# %%
"""
Fitting the Arrhenius Array
"""
from theano import shared

arr_data = shared(np.log(da2))
arr_err = shared((da2_err/2)/da2)
N = da2.shape[0]
tempk = temp + 273.15

# %%
"""
Stick Breaking 
"""
import pymc3.distributions.transforms as tr
from theano import tensor as tt
def stick_break(beta): 
    pr = tt.concatenate([[1], 
                         tt.extra_ops.cumprod(1 - beta)[:-1]])
    return beta * pr

# %%
m = 10
Q = pm.Model()
with Q: 
    # Global Component Distribution
    alpha = pm.Gamma('alpha', 
                         1., 1.)

    beta = pm.Beta('beta', 1., alpha, 
                      shape = m)

    K_w = stick_break(beta)
    
    K = pm.Deterministic('K', 
                        K_w/K_w.sum(axis = 0,
                                    keepdims = True))
    
    D = pm.Categorical('D', 
                       p = K, 
                       shape = N)

# %%
with Q: 
    # Diffusion Kinetics 
    ea = pm.Uniform('Ea',
                      lower = 120, 
                      upper = 500)
    
    d0 = pm.Uniform('d0',  
                      lower = 0.0, 
                      upper = 10000)

# %%
with Q: 
    # MDD/GSD
    a = pm.Uniform('a', lower = 0.00001, 
                  upper = 0.025, 
                  shape = m)

# %%
with Q: 
    
    a_domain = pm.Deterministic("a_domain",
                                a[D])
    phi_domain = pm.Deterministic('phi_domain',
                                  K[D])

# %%
with Q:
    R = 8.314e-3
    
    y2 = (((phi_domain/a_domain)**2) \
                 * d0 * np.exp(-ea/(R*tempk)))
    
    mu1 = tt.log(y2)

# %%
with Q: 
    arr_err_m = pm.HalfNormal('arr_err_m', 
                             sd = 0.05, 
                             shape = N)

# %%
with Q: 
    obs2 = weighted_Normal('obs2', mu1[:N-1],
                     arr_err_m[:N-1], 
                     observed = arr_data[:N-1], 
                          weight = 1)

# %%
Q.check_test_point()
# Out:
# alpha_log__            -1.00
# beta_logodds__        -13.86
# D                     -14.54
# Ea_interval__          -1.39
# d0_interval__          -1.39
# a_interval__          -13.86
# arr_err_m_log__       -16.17
# obs2              -748712.84
# Name: Log-probability of test_point, dtype: float64

# %%
SAMPLES = 100000
BURN = 200000
SEED = np.random.seed(123)

with Q:
    step1 = pm.CategoricalGibbsMetropolis([D]) 
    
    step2 = pm.Metropolis([alpha, 
                           beta,
                           d0, 
                           ea,
                           a], 
                         scaling = 10)
    
    
    trace = pm.sample(SAMPLES, tune = BURN, 
                     step = [step1,
                             step2],
                     random_seed = SEED)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# CompoundStep
# >CategoricalGibbsMetropolis: [D]
# >CompoundStep
# >>Metropolis: [a]
# >>Metropolis: [Ea]
# >>Metropolis: [d0]
# >>Metropolis: [beta]
# >>Metropolis: [alpha]
# >NUTS: [arr_err_m]
# Sampling 2 chains: 100%|██████████| 600000/600000 [31:35<00:00, 316.52draws/s]
# There were 44387 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.4121188211326314, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 7047 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6665929528994171, but should be close to 0.8. Try to increase the number of tuning steps.
# The gelman-rubin statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
"""
Number of Domains
"""
font = {'family' : 'Arial',
        'weight' : 'normal',
        'size'   : 15}

plt.rc('font', **font)

fig, ax = plt.subplots(1, 3, figsize = (9, 3))
n_comp = np.apply_along_axis(lambda x: np.unique(x).size, 
                            1, trace['D'][-SAMPLES::10])

n_comp =  n_comp+ 1
ncmp = n_comp.mean(axis = 0).astype(int)
bins = np.arange(n_comp.min() -2 , n_comp.max() + 2)

ax[0].hist(n_comp,
        bins=bins,
        density=True,
        lw= 2,
        alpha=0.75, 
       edgecolor = 'k', 
        facecolor = 'skyblue');

ax[0].set_xticks(bins + 0.5);
ax[0].set_xticklabels(bins);
ax[0].set_xlim(bins.min(),bins.max() + 1);

plot_w = np.arange(ncmp) + 1

ax[1].bar(plot_w - 0, trace['K'][-SAMPLES::10].mean(axis=0)[:ncmp],
          width=1., lw=2, 
      edgecolor = 'k', alpha = 0.75, 
         facecolor = 'skyblue');



ax[2].errorbar(np.linspace(1, ncmp,ncmp),
             trace['a'][-SAMPLES::10].mean(axis = 0)[:ncmp], 
             yerr = 2*trace['a'][-SAMPLES::10].std(axis = 0)[:ncmp], 
             fmt ='o', 
             markersize = 10, 
             markeredgecolor = 'k', 
             markerfacecolor = 'skyblue')

ax[2].set_xlabel('Domain');
ax[1].set_xlabel('Domain');
ax[2].set_ylabel('Domain size ($\mu$m)');
ax[1].set_ylabel('Mixture weight');
ax[0].set_xlabel('# of domains');
ax[0].set_ylabel('Posterior probability')
ax[2].set_ylim(0, 0.03)
ax[2].locator_params(axis='x', nbins=ncmp + 1)
ax[1].locator_params(axis='x', nbins=ncmp + 1)
ax[0].locator_params(axis='x', nbins=ncmp + 1)
ax[2].locator_params(axis='y', nbins=ncmp + 1)
ax[1].locator_params(axis='y', nbins=ncmp + 1)
ax[0].locator_params(axis='y', nbins=ncmp + 1)

ax[2].set_xlim(0, ncmp + 0.5)

plt.tight_layout()
plt.savefig('/Users/jackcarter/Desktop/chp3_figs/jc_a_ndom.pdf')

# %%
with Q: 
    ppc = pm.sample_ppc(trace,
                    1000)
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: sample_ppc() is deprecated.  Please use sample_posterior_predictive()
#   This is separate from the ipykernel package so we can avoid doing imports until
# 100%|██████████| 1000/1000 [00:22<00:00, 43.51it/s]

# %%
def arr_plot(ea, d0, a, temp): 
    R = 8.314e-3
    da2 = (d0/a.max()**2) * np.exp(-ea/(R*temp))
    
    return np.log(da2)

# %%
tplot = 10000/tempk
tplot2 = 10000/tempk

# Mean Predictive Models
Z1 = ppc['obs2'].mean(axis = 0)
low1, high1 = np.percentile(ppc['obs2'], [50 - 34, 50 + 34], axis = 0)

# %%
fig, ax = plt.subplots(1,1,figsize = (3,5))
plt.plot(tplot[:N], np.log(da2[:N]), 
          'o', markerfacecolor = 'grey', 
          markeredgecolor = 'k', 
          markersize = 9, label = 'Data')


plt.plot(tplot2,Z1, 'or',
             markerfacecolor = 'None',
            alpha = 1, 
             markeredgecolor = 'r', markeredgewidth = 0.9, 
            markersize = 9, 
            label = 'Model')

plt.errorbar(tplot2, Z1, yerr = 2*(high1 - low1),
           color = 'r', 
            fmt = 'o')

plt.xlabel('10$^{4}$/T (K$^{-1}$)')
plt.ylabel('ln(D/a$^{2}$)')
plt.locator_params(axis='y', nbins=6)
plt.locator_params(axis='x', nbins=6)

ax3 =plt.axes([0.28,0.2,0.35,0.15])

ax3.plot(tempk - 273.15, Z1 - np.log(da2), 'ok', 
        markeredgecolor = 'k', 
        markerfacecolor = 'lightgrey')
qqq = Z1 - np.log(da2)
ax3.axhline(0, lw = 1, ls = '--', 
           color = 'r')
ax3.set_ylabel('Residuals', fontsize = 8)
ax3.set_xlabel('Temperature ($^{o}$C)', fontsize = 8)
ax3.set_ylim(qqq.min() - 1, qqq.max() + 1)
ax3.tick_params(labelsize = 5)
ax3.locator_params(axis='x', nbins=6)
ax3.set_xlim(400, 1500)

plt.locator_params(axis='y', nbins=8)
plt.locator_params(axis='x', nbins=8)


ax5 = ax.twiny()

Tdc = np.array([400,  500, 800,  1400])
Tp = 10e3/(Tdc + 273.15)
labels = list(['400', '500', '800',   
              '1400'])
ax5.plot(tplot[:N], np.log(da2[:N]), alpha = 0)
plt.xlim(Tp.min() - 0.2, Tp.max()+ 1)
ax5.set_xlim(Tp.min() -0.2, Tp.max()+ 1)
ax5.set_xticks(Tp)
ax5.set_xticklabels(labels)
ax5.set_xlabel('Temperature ($^{o}$C)')

plt.ylim(-16, -7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-28963b2cddc4> in <module>()
#      11              markeredgecolor = 'r', markeredgewidth = 0.9,
#      12             markersize = 9,
# ---> 13             label = 'Model')
#      14
#      15 plt.errorbar(tplot2, Z1, yerr = 2*(high1 - low1),
#
# /Applications/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# /Applications/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /Applications/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# /Applications/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /Applications/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# /Applications/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (21,) and (20,)

# %%
fig, ax = plt.subplots(2, 4, figsize = (15,6))

z1 = ax[0,0].hist2d(x = trace['Ea'][-SAMPLES::10].round(2),
                   y = np.log(trace['d0'][-SAMPLES::10]/trace['a'][-SAMPLES::10][:,0]**2).round(2), normed = True, 
          cmap = 'viridis'); 

z2 = ax[0,1].hist2d(x = trace['Ea'][-SAMPLES::10].round(2),
         y = np.log(trace['d0'][-SAMPLES::10]/trace['a'][-SAMPLES::10][:,1]**2).round(2)
                  , normed = True, 
          cmap = 'viridis'); 


z3 = ax[0,2].hist2d(x = trace['Ea'][-SAMPLES::10].round(2),
        y = np.log(trace['d0'][-SAMPLES::10]/trace['a'][-SAMPLES::10][:,2]**2).round(2)
                  , normed = True, 
          cmap = 'viridis'); 

z3 = ax[0,3].hist2d(x = trace['Ea'][-SAMPLES::10].round(2),
        y = np.log(trace['d0'][-SAMPLES::10]/trace['a'][-SAMPLES::10][:,3]**2).round(2)
                  , normed = True, 
          cmap = 'viridis'); 


z3 = ax[1,0].hist2d(x = trace['Ea'][-SAMPLES::10].round(2),
        y = np.log(trace['d0'][-SAMPLES::10]/trace['a'][-SAMPLES::10][:,4]**2).round(2)
                  , normed = True, 
          cmap = 'viridis'); 


z3 = ax[1,1].hist2d(x = trace['Ea'][-SAMPLES::10].round(2),
        y = np.log(trace['d0'][-SAMPLES::10]/trace['a'][-SAMPLES::10][:,5]**2).round(2)
                  , normed = True, 
          cmap = 'viridis'); 


z3 = ax[1,2].hist2d(x = trace['Ea'][-SAMPLES::10].round(2),
        y = np.log(trace['d0'][-SAMPLES::10]/trace['a'][-SAMPLES::10][:,6]**2).round(2)
                  , normed = True, 
          cmap = 'viridis'); 

fig.delaxes(ax[1,3])



cbar = plt.colorbar(z2[3], ax=ax[1,3])
cbar.set_label('Relative Probability')



ax[0,0].set_ylabel('ln(D$_{0}$/a$^{2}$)')
ax[1,0].set_ylabel('ln(D$_{0}$/a$^{2}$)')

ax[1,1].set_xlabel('Activation Energy (kJmol$^{-1}$)')


ax[0,0].ticklabel_format(useOffset=False)
ax[0,1].ticklabel_format(useOffset=False)
ax[0,2].ticklabel_format(useOffset=False)
ax[0,3].ticklabel_format(useOffset=False)
ax[1,0].ticklabel_format(useOffset=False)
ax[1,1].ticklabel_format(useOffset=False)
ax[1,2].ticklabel_format(useOffset=False)
ax[1,3].ticklabel_format(useOffset=False)

plt.tight_layout()

# %%
fig, ax = plt.subplots(5, 5, figsize = (14, 5))
for i in range(ncmp): 
    plt.subplot(2, ncmp/2, i+1)
    plt.hist2d(trace['Ea'][-SAMPLES:],
                np.log(trace['d0'][-SAMPLES:]/trace['a'][-SAMPLES:][:,i]**2), 
               cmap = 'jet')


    plt.ylabel(f'ln(D$_{0}$/a$^{2}_{i+1}$)')
    plt.xlabel('E$_{a}$ (kJ/mol)')
    plt.colorbar(label = 'Sampling density')
    
plt.tight_layout() 
plt.savefig('/Users/jackcarter/Desktop/chp3_figs/jc_a_diff_kin.pdf')

# %%
def arr_plot(ea, d0, a, temp, phi): 
    R = 8.314e-3
    da2 = (phi/a)**2 * d0 * np.exp(-ea/(R*temp))
    
    return np.log(da2)

temp = np.linspace(400, 1400, 10)

# %%
font = {'family' : 'Arial',
        'weight' : 'normal',
        'size'   : 15}

plt.rc('font', **font)
sns.set_style('ticks')

fig,ax = plt.subplots(1,2, figsize = (9,5))
ax[0].plot(tplot[:N], np.log(da2[:N]), 
          'o', markerfacecolor = 'grey', 
          markeredgecolor = 'k', 
          markersize = 9, label = 'Data')


ax[0].plot(tplot[:N-1],Z1[:N], 'or',
             markerfacecolor = 'None',
            alpha = 1, 
             markeredgecolor = 'r', markeredgewidth = 0.9, 
            markersize = 9, 
            label = 'Model')

ax[0].errorbar(tplot[:N-1], Z1[:N], yerr = 2*(high1 - low1),
           color = 'r', 
            fmt = 'o')

ax[0].set_xlabel('10$^{4}$/T (K$^{-1}$)')
ax[0].set_ylabel('ln(D/a$^{2}$)')
ax[0].locator_params(axis='y', nbins=6)
ax[0].locator_params(axis='x', nbins=6)



ax[1].plot(tplot, np.log(da2[:N]), 
          'o', markerfacecolor = 'grey', 
          markeredgecolor = 'k', 
          markersize = 9, label = 'Data')

temp = np.linspace(400, 1400, 10)
for i in range(ncmp): 
    ax[1].plot(10000/temp, 
            arr_plot(trace['Ea'][-1000:].mean(axis = 0)
                     , trace['d0'][-1000:].mean(axis = 0), 
                     trace['a'][-1000:].mean(axis = 0)[i], 
                    temp, 
                    trace['K'][-1000:].mean(axis = 0)[i]), 
              label = f'Domain$_{i+1}$')


ax[1].set_xlabel('10$^{4}$/T (K$^{-1}$)')
ax[1].locator_params(axis='y', nbins=6)
ax[1].locator_params(axis='x', nbins=6)
ax[1].legend(fontsize = 8, 
            loc = 3)


ax3 =plt.axes([0.19,0.25,0.13,0.15])

ax3.plot(tempk[:N-1] - 273.15, Z1[:N] - np.log(da2[:N-1]), 'ok', 
        markeredgecolor = 'k', 
        markerfacecolor = 'lightgrey')
qqq = Z1[:N] - np.log(da2[:N-1])
ax3.axhline(0, lw = 1, ls = '--', 
           color = 'r')
ax3.set_ylabel('Residuals', fontsize = 6)
ax3.set_xlabel('Temperature ($^{o}$C)', fontsize = 6)
ax3.set_ylim(qqq.min() - 1, qqq.max() + 1)
ax3.tick_params(labelsize = 5)
ax3.locator_params(axis='x', nbins=6)
ax3.set_xlim(400, 1500)

plt.locator_params(axis='y', nbins=8)
plt.locator_params(axis='x', nbins=8)


ax5 = ax[0].twiny()
Tdc = np.array([400,  500, 800,  1400])
Tp = 10e3/(Tdc + 273.15)
labels = list(['400', '500', '800',   
              '1400'])
ax5.plot(tplot[:N], np.log(da2[:N]), alpha = 0)
ax[0].set_xlim(Tp.min() - 0.2, Tp.max()+ 1)
ax5.set_xlim(Tp.min() -0.2, Tp.max()+ 1)
ax5.set_xticks(Tp)
ax5.set_xticklabels(labels)
ax5.set_xlabel('Temperature ($^{o}$C)')


ax6 = ax[1].twiny()
Tdc = np.array([400,  500, 800,  1400])
Tp = 10e3/(Tdc + 273.15)
labels = list(['400', '500', '800',   
              '1400'])
ax6.plot(tplot[:N], np.log(da2[:N]), alpha = 0)
ax[1].set_xlim(Tp.min() - 0.2, Tp.max()+ 1)
ax6.set_xlim(Tp.min() -0.2, Tp.max()+ 1)
ax6.set_xticks(Tp)
ax6.set_xticklabels(labels)
ax6.set_xlabel('Temperature ($^{o}$C)')
ax[1].set_ylim(-20, -6)
ax[0].set_ylim(-20, -6)
ax[1].set_yticks([])

ax[0].text(6.2, -19.6, 'A', 
          fontsize = 16, 
          fontweight = 'bold')

ax[1].text(15, -7.5, 'B', 
          fontsize = 16, 
          fontweight = 'bold')

plt.tight_layout()


plt.savefig('/Users/jackcarter/Desktop/chp3_figs/jc_a_model.pdf')
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
df_out_model = pd.DataFrame({
                      'model':Z1[:N], 
                      'data': da2[:N], 
                       'data_err': da2_err[:N], 
                      'model_err': low1[:N] - high1[:N], 
                      'tempk': tempk[:N]})

df_out_trace = pd.DataFrame({'ea': trace['Ea'][-SAMPLES::10], 
                      'd0': trace['d0'][-SAMPLES::10], 
                      'a1': trace['a'][:,0][::10].mean(axis = 0), 
                      'a2': trace['a'][:,1][::10].mean(axis = 0), 
                      'a3': trace['a'][:,2][::10].mean(axis = 0)})


df_age_out = pd.DataFrame({"age_plot":age_plot, 
                          "age_err_plot":age_plot_err, 
                          "ar39_plot":ar39_plot})


df_out_model.to_csv('jc_an_model.csv')
df_out_trace.to_csv('jc_an_trace.csv')
df_age_out.to_csv('jc_an_age_spec.csv')

# %%
trace['Ea'][-SAMPLES::10].mean(), trace['Ea'][-SAMPLES::10].std()
# Out:
# (229.55047789113027, 9.28658603961838)

# %%
y = np.log(trace['d0'][-SAMPLES::10])

# %%
y.mean(), y.std()
# Out:
# (8.501732393100625, 0.34013285189528136)
